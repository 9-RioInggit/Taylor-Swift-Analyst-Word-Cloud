# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud, STOPWORDS
print ('Wordcloud is installed and imported!')
# Out:
# Wordcloud is installed and imported!

# %%
TS_Ly = open('taylor_swift_lyrics.csv', 'r').read()
    
print ('File downloaded and saved!')
# Out:
# File downloaded and saved!

# %%
stopwords = set(STOPWORDS)

# %%
from PIL import Image

# %%
# instantiate a word cloud object
ts_wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
ts_wc.generate(TS_Ly)

# %%
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

# display the word cloud
plt.imshow(ts_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import folium

# %%
### type your answer here
Hlatitude = -6.171336
Hlongitude = 106.783918

JakbarLat = -6.1674
JakbarLong = 106.7637

jakbar_map = folium.Map(location=[JakbarLat, JakbarLong], zoom_start=12)
    
# display  map
jakbar_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
myhome = folium.map.FeatureGroup()

myhome.add_child(
        folium.CircleMarker(
            [Hlatitude, Hlongitude],
            radius=8, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

folium.Marker([Hlatitude, Hlatitude], popup='Home').add_to(jakbar_map)
# add incidents to map
jakbar_map.add_child(myhome)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
